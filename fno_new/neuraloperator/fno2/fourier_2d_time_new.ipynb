# %%
import torch.nn.functional as F
from utilities3 import *
from timeit import default_timer

# %%
torch.manual_seed(0)
np.random.seed(0)

# %%
class SpectralConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, modes1, modes2):
        super(SpectralConv2d, self).__init__()

        """
        2D Fourier layer. It does FFT, linear transform, and Inverse FFT.    
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1 #Number of Fourier modes to multiply, at most floor(N/2) + 1
        self.modes2 = modes2

        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, dtype=torch.cfloat))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, dtype=torch.cfloat))

    # Complex multiplication
    def compl_mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        batchsize = x.shape[0]
        #Compute Fourier coeffcients up to factor of e^(- something constant)
        x_ft = torch.fft.rfft2(x)

        # Multiply relevant Fourier modes
        out_ft = torch.zeros(batchsize, self.out_channels,  x.size(-2), x.size(-1)//2 + 1, dtype=torch.cfloat, device=x.device)
        out_ft[:, :, :self.modes1, :self.modes2] = \
            self.compl_mul2d(x_ft[:, :, :self.modes1, :self.modes2], self.weights1)
        out_ft[:, :, -self.modes1:, :self.modes2] = \
            self.compl_mul2d(x_ft[:, :, -self.modes1:, :self.modes2], self.weights2)

        #Return to physical space
        x = torch.fft.irfft2(out_ft, s=(x.size(-2), x.size(-1)))
        return x

# %%
class MLP(nn.Module):
    def __init__(self, in_channels, out_channels, mid_channels):
        super(MLP, self).__init__()
        self.mlp1 = nn.Conv2d(in_channels, mid_channels, 1)
        self.mlp2 = nn.Conv2d(mid_channels, out_channels, 1)

    def forward(self, x):
        x = self.mlp1(x)
        x = F.gelu(x)
        x = self.mlp2(x)
        return x

# %%
class FNO2d(nn.Module):
    def __init__(self, modes1, modes2, width):
        super(FNO2d, self).__init__()

        """
        The overall network. It contains 4 layers of the Fourier layer.
        1. Lift the input to the desire channel dimension by self.fc0 .
        2. 4 layers of the integral operators u' = (W + K)(u).
            W defined by self.w; K defined by self.conv .
        3. Project from the channel space to the output space by self.fc1 and self.fc2 .
        
        input: the solution of the previous 10 timesteps + 2 locations (u(t-10, x, y), ..., u(t-1, x, y),  x, y)
        input shape: (batchsize, x=64, y=64, c=12)
        output: the solution of the next timestep
        output shape: (batchsize, x=64, y=64, c=1)
        """

        self.modes1 = modes1
        self.modes2 = modes2
        self.width = width
        self.padding = 8 # pad the domain if input is non-periodic

        self.p = nn.Linear(12, self.width) # input channel is 12: the solution of the previous 10 timesteps + 2 locations (u(t-10, x, y), ..., u(t-1, x, y),  x, y)
        self.conv0 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv1 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv2 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv3 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.mlp0 = MLP(self.width, self.width, self.width)
        self.mlp1 = MLP(self.width, self.width, self.width)
        self.mlp2 = MLP(self.width, self.width, self.width)
        self.mlp3 = MLP(self.width, self.width, self.width)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)
        self.norm = nn.InstanceNorm2d(self.width)
        self.q = MLP(self.width, 1, self.width * 4) # output channel is 1: u(x, y)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)
        x = self.p(x)
        x = x.permute(0, 3, 1, 2)
        # x = F.pad(x, [0,self.padding, 0,self.padding]) # pad the domain if input is non-periodic

        x1 = self.norm(self.conv0(self.norm(x)))
        x1 = self.mlp0(x1)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.norm(self.conv1(self.norm(x)))
        x1 = self.mlp1(x1)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.norm(self.conv2(self.norm(x)))
        x1 = self.mlp2(x1)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.norm(self.conv3(self.norm(x)))
        x1 = self.mlp3(x1)
        x2 = self.w3(x)
        x = x1 + x2

        # x = x[..., :-self.padding, :-self.padding] # pad the domain if input is non-periodic
        x = self.q(x)
        x = x.permute(0, 2, 3, 1)
        return x

    def get_grid(self, shape, device):
        batchsize, size_x, size_y = shape[0], shape[1], shape[2]
        gridx = torch.tensor(np.linspace(0, 1, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1).repeat([batchsize, 1, size_y, 1])
        gridy = torch.tensor(np.linspace(0, 1, size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1).repeat([batchsize, size_x, 1, 1])
        return torch.cat((gridx, gridy), dim=-1).to(device)

# %%
TRAIN_PATH = 'data/ns_V1e-4_N10000_T30.mat'
TEST_PATH = 'data/ns_data.mat'

ntrain = 100
ntest = 20

modes = 12
width = 20

batch_size = 20
learning_rate = 0.001
epochs = 20
iterations = epochs*(ntrain//batch_size)

path = 'ns_fourier_2d_time_N'+str(ntrain)+'_ep' + str(epochs) + '_m' + str(modes) + '_w' + str(width)
path_model = 'model/'+path
path_train_err = 'results/'+path+'train.txt'
path_test_err = 'results/'+path+'test.txt'
path_image = 'image/'+path

sub = 1
S = 64
#S1 = 64
T_in = 10
T = 30 # T=40 for V1e-3; T=20 for V1e-4; T=10 for V1e-5;
step = 1

# %%
reader = MatReader(TRAIN_PATH)
train_a = reader.read_field('u')[:ntrain,::sub,::sub,:T_in]
train_u = reader.read_field('u')[:ntrain,::sub,::sub,T_in:T+T_in]

reader = MatReader(TEST_PATH)
test_a = reader.read_field('u')[-ntest:,::sub,::sub,:T_in]
test_u = reader.read_field('u')[-ntest:,::sub,::sub,T_in:T+T_in]

print(train_u.shape)
print(test_u.shape)
assert (S == train_u.shape[-2])
assert (T == train_u.shape[-1])

train_a = train_a.reshape(ntrain,S,S,T_in)
test_a = test_a.reshape(ntest,S,S,T_in)

train_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(train_a, train_u), batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(test_a, test_u), batch_size=batch_size, shuffle=False)
# Out:
# torch.Size([100, 64, 64, 30])
# torch.Size([20, 64, 64, 30])

# %%
device = "cuda" # "cpu"
model = FNO2d(modes, modes, width).to(device)
#model = FNO2d(modes, modes, width).cuda()

print(count_params(model))
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-192)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) # weight decay causes errors

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=iterations)

myloss = LpLoss(size_average=False)
for ep in range(10):
    model.train()
    t1 = default_timer()
    train_l2_step = 0
    train_l2_full = 0
    
    print(ep, t1)
    for xx, yy in train_loader:
        loss = 0
        xx = xx.to(device)
        yy = yy.to(device)

        for t in range(0, T, step):
        #for t in range(0, 2, step):
            y = yy[..., t:t + step]
            im = model(xx)
            #print(f"im.shape: {im.shape}")
            #print(f"xx.shape: {xx.shape}")

            #print(f"im.reshape(batch_size, -1).shape: {im.reshape(batch_size, -1).shape}")
            #print(f"y.reshape(batch_size, -1).shape: {y.reshape(batch_size, -1).shape}")
            loss += myloss(im.reshape(batch_size, -1), y.reshape(batch_size, -1))
            
            # kk=
            # print(f"kk.shape: {kk.shape}")
            if t == 0:
                pred = im
            else:
                pred = torch.cat((pred, im), -1)

            xx = torch.cat((xx[..., step:], im), dim=-1)
            print(f"loss: {loss}")
            print(f"im.device: {im.device}")
            print(f"y.device: {y.device}")
            #print(f"xx[...,step:].shape: {xx[...,step:].shape}")
        train_l2_step += loss.item()
        print(f"pred.reshape(batch_size, -1).shape: {pred.reshape(batch_size, -1).shape}")
        print(f"yy.reshape(batch_size, -1).shape: {yy.reshape(batch_size, -1).shape}")
        l2_full = myloss(pred.reshape(batch_size, -1), yy.reshape(batch_size, -1))
        train_l2_full += l2_full.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
    # raise ValueError
    test_l2_step = 0
    test_l2_full = 0
    with torch.no_grad():
        for xx, yy in test_loader:
            loss = 0
            xx = xx.to(device)
            yy = yy.to(device)

            for t in range(0, T, step):
                y = yy[..., t:t + step]
                im = model(xx)
                loss += myloss(im.reshape(batch_size, -1), y.reshape(batch_size, -1))
                
                
                if t == 0:
                    pred = im
                    test_inputs = xx[..., -step :]
                    test_labels = y
                    y_old = y
                else:
                    pred = torch.cat((pred, im), -1)
                    test_inputs = torch.cat((test_inputs, y_old), -1)
                    y_old =y
                    test_labels = torch.cat((test_labels, y), -1)
                    

                xx = torch.cat((xx[..., step:], im), dim=-1)

            test_l2_step += loss.item()
            test_l2_full += myloss(pred.reshape(batch_size, -1), yy.reshape(batch_size, -1)).item()

    t2 = default_timer()
# Out:
# 928661
# 0 6840688.004824889
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 20.08306884765625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 40.19737243652344
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 60.192447662353516
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 80.17236328125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 100.15892791748047
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 120.14404296875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 140.1502685546875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 160.14376831054688
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 180.13685607910156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 200.1498260498047
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 220.17333984375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 240.1876678466797
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 260.19720458984375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 280.2153015136719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 300.2187194824219
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 320.23883056640625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 340.2527160644531
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 360.27850341796875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 380.3074951171875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 400.3348388671875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 420.3676452636719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 440.3919982910156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 460.4137268066406
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 480.4438171386719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 500.45849609375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 520.4806518554688
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 540.5032958984375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 560.5247802734375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 580.5521850585938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 600.5672607421875
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 20.026304244995117
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 39.72235107421875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 59.56664276123047
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 79.31364440917969
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 98.94221496582031
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 118.50594329833984
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 138.13198852539062
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 157.75262451171875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 177.48716735839844
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 197.3548126220703
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 217.46011352539062
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 237.5300750732422
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 257.5811462402344
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 277.60577392578125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 297.63275146484375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 317.66607666015625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 337.7214660644531
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 357.7983093261719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 377.89007568359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 397.9840393066406
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 418.0753173828125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 438.1506042480469
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 458.21484375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 478.2684631347656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 498.3179931640625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 518.365478515625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 538.4121704101562
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 558.4609985351562
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 578.5045776367188
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 598.5382080078125
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 19.222000122070312
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 38.134315490722656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 57.08912658691406
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 76.03668212890625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 95.01250457763672
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 114.0595932006836
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 133.17794799804688
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 152.390380859375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 171.69464111328125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 191.00196838378906
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 210.59780883789062
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 230.12147521972656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 249.66375732421875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 269.19915771484375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 288.7583312988281
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 308.3392639160156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 327.9398193359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 347.5815124511719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 367.25775146484375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 386.95587158203125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 406.71844482421875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 426.517578125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 446.3523254394531
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 466.20050048828125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 486.0547180175781
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 505.9162902832031
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 525.800537109375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 545.7195434570312
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 565.6571044921875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 585.593017578125
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 18.38137435913086
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 36.849159240722656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 55.453941345214844
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 74.16024780273438
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 92.94624328613281
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 111.818115234375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 130.77728271484375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 149.76077270507812
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 168.83010864257812
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 188.08596801757812
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 207.43661499023438
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 226.85215759277344
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 246.29380798339844
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 265.7582092285156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 285.25927734375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 304.7809753417969
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 324.3487548828125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 343.9671325683594
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 363.6573791503906
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 383.4270324707031
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 403.26507568359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 423.1398620605469
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 443.02490234375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 462.910888671875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 482.80615234375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 502.70751953125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 522.6202392578125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 542.5535888671875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 562.5050659179688
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 582.4664306640625
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 18.129629135131836
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 36.21864700317383
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 54.43782043457031
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 72.74552154541016
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 91.15840911865234
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 109.6842041015625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 128.3197479248047
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 147.04769897460938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 165.86703491210938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 184.7494659423828
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 203.71885681152344
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 222.70068359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 241.72203063964844
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 260.782958984375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 279.88238525390625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 299.01165771484375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 318.1662902832031
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 337.36346435546875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 356.6152038574219
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 375.94158935546875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 395.35418701171875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 414.8294677734375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 434.3763732910156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 453.99737548828125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 473.6706237792969
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 493.3722839355469
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 513.1113891601562
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 532.8883056640625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 552.6697998046875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 572.4423217773438
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# 1 6840689.560464776
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 17.829975128173828
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 35.6820068359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 53.66307830810547
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 71.71722412109375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 89.90204620361328
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 108.21531677246094
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 126.65328979492188
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 145.23422241210938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 163.9542694091797
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 182.69281005859375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 201.62075805664062
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 220.51759338378906
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 239.46432495117188
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 258.4450988769531
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 277.4637145996094
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 296.52886962890625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 315.6376647949219
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 334.79425048828125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 354.0252685546875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 373.3446960449219
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 392.781982421875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 412.28326416015625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 431.84014892578125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 451.44476318359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 471.0738525390625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 490.7211608886719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 510.4106750488281
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 530.1588745117188
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 549.9349365234375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 569.7105102539062
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 17.17912483215332
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 34.51161193847656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 52.02721405029297
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 69.6832046508789
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 87.48876953125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 105.43913269042969
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 123.528076171875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 141.76571655273438
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 160.16091918945312
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 178.63702392578125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 197.24404907226562
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 215.91885375976562
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 234.65557861328125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 253.40187072753906
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 272.197265625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 291.0221252441406
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 309.8533630371094
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 328.75482177734375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 347.72515869140625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 366.7366943359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 385.88775634765625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 405.1922607421875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 424.57647705078125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 444.003173828125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 463.51177978515625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 483.04620361328125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 502.58428955078125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 522.193359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 541.90380859375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 561.6199951171875
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 16.78417205810547
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 33.70587158203125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 50.88080596923828
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 68.2294692993164
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 85.744140625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 103.45547485351562
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 121.34342956542969
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 139.35704040527344
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 157.5177764892578
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 175.8430633544922
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 194.22836303710938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 212.67507934570312
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 231.18528747558594
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 249.70797729492188
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 268.2759094238281
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 286.91357421875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 305.6090087890625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 324.3836669921875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 343.28594970703125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 362.32086181640625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 381.5180969238281
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 400.86663818359375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 420.332275390625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 439.8782958984375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 459.50396728515625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 479.2201232910156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 499.0022888183594
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 518.856201171875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 538.7119750976562
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 558.5336303710938
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 16.211631774902344
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 32.59830856323242
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 49.29142379760742
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 66.20470428466797
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 83.30609130859375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 100.61676025390625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 118.12632751464844
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 135.80516052246094
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 153.6493682861328
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 171.668701171875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 189.79656982421875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 208.00900268554688
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 226.28468322753906
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 244.6157684326172
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 263.01422119140625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 281.4836120605469
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 300.05859375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 318.7476501464844
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 337.54925537109375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 356.49481201171875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 375.56097412109375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 394.7623596191406
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 414.0957946777344
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 433.5207214355469
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 453.02496337890625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 472.60772705078125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 492.2434997558594
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 511.9317321777344
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 531.6719970703125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 551.4899291992188
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 15.802652359008789
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 31.83062171936035
# im.device: cuda:0
# y.device: cuda:0
# ...
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 6.6581268310546875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 12.590262413024902
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 18.781330108642578
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 25.20987319946289
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 32.0140266418457
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 39.475685119628906
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 47.21192169189453
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 55.4885139465332
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 64.54828643798828
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 74.40544128417969
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 84.46098327636719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 94.50184631347656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 105.14822387695312
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 116.41213989257812
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 128.25115966796875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 140.7043914794922
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 153.82623291015625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 167.80258178710938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 182.316650390625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 197.54403686523438
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 213.69271850585938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 230.84356689453125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 248.7307891845703
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 267.041259765625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 285.83489990234375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 305.19287109375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 325.14404296875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 345.9818115234375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 367.951416015625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 390.6505126953125
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 6.143775939941406
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 11.670806884765625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 17.585485458374023
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 23.90056800842285
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 30.46518325805664
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 37.62451934814453
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 45.28645706176758
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 53.58503723144531
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 62.44269943237305
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 71.82858276367188
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 81.64384460449219
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 92.08041381835938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 103.09558868408203
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 114.41786193847656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 126.34295654296875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 138.930419921875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 152.2830047607422
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 166.4039306640625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 181.27291870117188
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 197.11508178710938
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 213.54238891601562
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 230.18324279785156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 247.02195739746094
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 264.00872802734375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 281.2171630859375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 298.774169921875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 316.82464599609375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 335.7915954589844
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 355.7005920410156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 376.3445129394531
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 6.378700256347656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 11.765129089355469
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 17.304466247558594
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 23.39687156677246
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 29.929716110229492
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 36.881526947021484
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 44.153472900390625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 52.17219161987305
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 60.944095611572266
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 70.23622131347656
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 80.18258666992188
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 90.89126586914062
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 102.12053680419922
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 113.98987579345703
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 126.41264343261719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 139.68673706054688
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 153.75653076171875
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 168.45306396484375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 183.87396240234375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 199.96728515625
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 216.94622802734375
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 234.51853942871094
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 252.29067993164062
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 270.35595703125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 288.403564453125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 306.40655517578125
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 324.7273864746094
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 343.8295593261719
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 363.9710998535156
# im.device: cuda:0
# y.device: cuda:0
# im.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# y.reshape(batch_size, -1).shape: torch.Size([20, 4096])
# loss: 385.26849365234375
# im.device: cuda:0
# y.device: cuda:0
# pred.reshape(batch_size, -1).shape: torch.Size([20, 122880])
# yy.reshape(batch_size, -1).shape: torch.Size([20, 122880])

# %%
print(ep, t2 - t1, train_l2_step / ntrain / (T / step), train_l2_full / ntrain, test_l2_step / ntest / (T / step),
          test_l2_full / ntest)
# Out:
# 9 19.46539271902293 0.6165839131673178 0.701437406539917 1.8240482584635416 1.659691619873047

# %%
# #test_samples = test_loader.dataset

# import numpy as np

# #np.shape(test_samples)
# #test_samples[10,0]

# test_loaders = {20: test_loader}
# test_samples = test_loaders[20].dataset
# print(f"test_samples.sahpe: {test_samples.shape}")
# np.shape(test_samples[0,:,:,:][1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 10
#       8 test_loaders = {20: test_loader}
#       9 test_samples = test_loaders[20].dataset
# ---> 10 print(f"test_samples.sahpe: {test_samples.shape}")
#      11 np.shape(test_samples[0,:,:,:][1])
#
# AttributeError: 'TensorDataset' object has no attribute 'shape'

# %%
import matplotlib.pyplot as plt
rows = 3
fig = plt.figure(figsize=(7, 7))

for index in range(rows):
    data = test_inputs[0,:,:,3*index ]
    data1 = test_labels[0,:,:,3*index]
    out = pred[0,:,:,3*index]

    # Input x
    x = data
    # Ground-truth
    y = data1
    # Model prediction
    #out = model(xx)

    ax = fig.add_subplot(rows, 3, index*3 + 1)
    ax.imshow(x)
    if index == 0:
        ax.set_title('Input x')
    plt.xticks([], [])
    plt.yticks([], [])

    ax = fig.add_subplot(rows, 3, index*3 + 2)
    ax.imshow(y)
    if index == 0:
        ax.set_title('Ground-truth y')
    plt.xticks([], [])
    plt.yticks([], [])

    ax = fig.add_subplot(rows, 3, index*3 + 3)
    ax.imshow(out)
    if index == 0:
        ax.set_title('Model prediction')
    plt.xticks([], [])
    plt.yticks([], [])

fig.suptitle('Inputs, ground-truth output and prediction.', y=0.98)
plt.tight_layout()
fig.show()
# Out:
# /tmp/ipykernel_272646/2420219154.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
out
# Out:
# tensor([[1.1476, 1.3136, 1.4745,  ..., 0.5830, 0.7813, 0.9697],
#         [1.2484, 1.3972, 1.5455,  ..., 0.7117, 0.9054, 1.0849],
#         [1.4145, 1.5552, 1.6971,  ..., 0.8831, 1.0801, 1.2574],
#         ...,
#         [0.9239, 1.1264, 1.3158,  ..., 0.2371, 0.4787, 0.7072],
#         [1.0137, 1.2086, 1.3935,  ..., 0.3563, 0.5869, 0.8059],
#         [1.0763, 1.2587, 1.4361,  ..., 0.4688, 0.6815, 0.8838]])
